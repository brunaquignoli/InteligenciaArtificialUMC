# %% [markdown]
# 1. Hello, World!
# o Imprima "Hello, World!" no console.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# 2. Soma de Dois Números
# o Crie um programa que peça ao usuário dois números e exiba a soma
# deles

# %%
number1 = float(input("Insira o primeiro número: "))
number2 = float(input("Insira o segundo número: "))
print("resultado:", number1 + number2)
# Out:
# Insira o primeiro número: 6
# Insira o segundo número: 6
# resultado: 12.0

# %% [markdown]
# 3. Cálculo da Área do Círculo
# o Solicite o raio de um círculo e calcule sua área. Use a fórmula área =
# π * r².

# %%
r = float(input("Insira o raio do circulo: "))
resultado = 3.14 * r**2
print("Resultado da área do círculo: ", resultado)
# Out:
# Insira o raio do circulo: 5
# Resultado da área do círculo:  78.5
